# %% [markdown]
# Syed Imran Yousaf
# 2530-4025

# %%
install.packages("rvest")
install.packages("dplyr")

library(rvest)
library(dplyr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
url <- "https://www.worldometers.info/world-population/population-by-country/"
page <- read_html(url)

# %%
tables <- page %>% html_table(fill = TRUE)

length(tables)
# Out:
# [1] 1

# %%
population_data <- tables[[1]]

# %%
nrow(population_data)
head(population_data)
tail(population_data)
# Out:
# [1] 233
#   # Country (or dependency) Population 2025 Yearly Change Net Change
# 1 1 India                   1,463,865,525   0.89%         12,929,734
# 2 2 China                   1,416,096,094   −0.23%        −3,225,184
# 3 3 United States           347,275,807     0.54%         1,849,236
# 4 4 Indonesia               285,721,236     0.79%         2,233,305
# 5 5 Pakistan                255,219,554     1.57%         3,950,390
# 6 6 Nigeria                 237,527,782     2.08%         4,848,304
#   Density (P/Km²) Land Area (Km²) Migrants (net) Fert. Rate Median Age
# 1 492             2,973,190       −495,753       1.94       28.8
# 2 151             9,388,211       −268,126       1.02       40.1
# 3 38              9,147,420       1,230,663      1.62       38.5
# 4 158             1,811,570       −39,509        2.10       30.4
# 5 331             770,880         −1,235,336     3.50       20.6
# 6 261             910,770         −15,258        4.30       18.1
# ...

# %%
colnames(population_data) <- c(
  "Rank", "Country", "Population", "Yearly_Change",
  "Net_Change", "Density", "Land_Area",
  "Migrants", "Fertility_Rate",
  "Median_Age", "Urban_Population",
  "World_Share"
)

# %%
head(population_table)
# Out:
#   # Country (or dependency) Population 2025 Yearly Change Net Change
# 1 1 India                   1,463,865,525   0.89%         12,929,734
# 2 2 China                   1,416,096,094   −0.23%        −3,225,184
# 3 3 United States           347,275,807     0.54%         1,849,236
# 4 4 Indonesia               285,721,236     0.79%         2,233,305
# 5 5 Pakistan                255,219,554     1.57%         3,950,390
# 6 6 Nigeria                 237,527,782     2.08%         4,848,304
#   Density (P/Km²) Land Area (Km²) Migrants (net) Fert. Rate Median Age
# 1 492             2,973,190       −495,753       1.94       28.8
# 2 151             9,388,211       −268,126       1.02       40.1
# 3 38              9,147,420       1,230,663      1.62       38.5
# 4 158             1,811,570       −39,509        2.10       30.4
# 5 331             770,880         −1,235,336     3.50       20.6
# 6 261             910,770         −15,258        4.30       18.1
#   Urban Pop % World Share
# ...

# %%
population_data <- as.data.frame(population_table)

colnames(population_data) <- c(
  "Rank", "Country", "Population", "Yearly_Change",
  "Net_Change", "Density", "Land_Area",
  "Migrants", "Fert_Rate", "Med_Age",
  "Urban_Pop", "World_Share"
)

head(population_data)
# Out:
#   Rank Country       Population    Yearly_Change Net_Change Density Land_Area
# 1 1    India         1,463,865,525 0.89%         12,929,734 492     2,973,190
# 2 2    China         1,416,096,094 −0.23%        −3,225,184 151     9,388,211
# 3 3    United States 347,275,807   0.54%         1,849,236  38      9,147,420
# 4 4    Indonesia     285,721,236   0.79%         2,233,305  158     1,811,570
# 5 5    Pakistan      255,219,554   1.57%         3,950,390  331     770,880
# 6 6    Nigeria       237,527,782   2.08%         4,848,304  261     910,770
#   Migrants   Fert_Rate Med_Age Urban_Pop World_Share
# 1 −495,753   1.94      28.8    37.1%     17.78%
# 2 −268,126   1.02      40.1    67.5%     17.20%
# 3 1,230,663  1.62      38.5    82.8%     4.22%
# 4 −39,509    2.10      30.4    59.6%     3.47%
# 5 −1,235,336 3.50      20.6    34.4%     3.10%
# 6 −15,258    4.30      18.1    54.9%     2.89%
